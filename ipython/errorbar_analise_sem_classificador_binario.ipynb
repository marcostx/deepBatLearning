# %% [markdown]
# # Estatísticas Gerais:  Accuracy, Precision, F1, Recall
#
# Neste notebook, são apresentados os gráficos de errorbar para as 4 métricas (accuracy, precision,f1 e recall). Os valores de cada gráfico representam a média obtida através de uma validação cruzada com k=10 folds, juntamente com o desvio padrão.

# %%
import pandas as pd 
import numpy as np
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
acc_cnn = [0.89893617021276595
,0.85106382978723405
,0.88172043010752688
,0.9027027027027027
,0.94054054054054059
,0.875
,0.88586956521739135
,0.92896174863387981
,0.85635359116022103
,0.89502762430939231]
acc_mlp = [0.78191489361702127
,0.82978723404255317
,0.79569892473118276
,0.81621621621621621
,0.80540540540540539
,0.80978260869565222
,0.81521739130434778
,0.81420765027322406
,0.8066298342541437
,0.77348066298342544]
acc_dfa = [0.46685714285714286
,0.48057142857142859
,0.47657142857142859
,0.4914187643020595
,0.47368421052631576
,0.48769318832283914
,0.47534403669724773
,0.48222477064220182
,0.47933409873708382
,0.47876004592422505]
plt.plot(acc_cnn,label="CNN")
plt.plot(acc_mlp,label='MLP')
plt.plot(acc_dfa,label='DFA')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# calculando as medias e desvios
mean_acc_ACU = np.mean(acc_cnn)
mean_mlp_ACC = np.mean(acc_mlp)
mean_dfa_ACC = np.mean(acc_dfa)
std_acc_ACC = np.std(acc_cnn)
std_mlp_ACC = np.std(acc_mlp)
std_dfa_ACC = np.std(acc_dfa)

mean_vals_acu = [mean_acc_ACU,mean_mlp_ACC,mean_dfa_ACC]
std_vals_acu = [std_acc_ACC,std_mlp_ACC,std_dfa_ACC]
print(mean_vals_acu)
# Out:
# [0.89161762026716551, 0.80483408215231722, 0.47924591151519724]

# %%
titles = ['CNN', 'MLP', 'DFA']
width=0.35
y_pos  = np.arange(len(titles))

fig, ax = plt.subplots()
fig.set_size_inches(15.5, 10.5)
ax.bar(y_pos, mean_vals_acu, width,yerr=std_vals_acu, align='edge',
        color='red', ecolor='black')
ax.set_xticks(y_pos + width/2)
ax.set_xticklabels(('CNN', 'MLP', 'DFA'))
plt.ylim(0.0, 1.0)
ax.set_xlabel('Model')
ax.set_ylabel('Mean')
ax.set_title('Accuracy')
plt.show()
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
# precision 
pred_cnn = [0.90294755415623029
,0.86556759614113921
, 0.88915602898050716
, 0.90320579320579319
,0.94523194523194531
,0.87653865022311328
,0.89544451135657421
,0.93572462752790631
,0.86539984642314716
,0.90375379684771961]
pred_mlp = [0.82410397312686845
,0.86006189911204156
,0.81277969751346613
,0.81877912395153774
,0.83261035950691131
,0.80928042971521219
,0.83868829152214264
,0.82365551380038615
,0.82911496953169339
,0.78922432693150923]
pred_dfa = [0.48613152406965726
,0.47783098848089445
,0.45751596391739568
,0.46771387829053729
,0.44454516926930498
,0.47846549684111961
,0.47501842526811588
,0.46860098295992064
,0.45647351726787999
,0.49189454197663074]
plt.plot(pred_cnn,label="CNN")
plt.plot(pred_mlp,label='MLP')
plt.plot(pred_dfa,label='DFA')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# calculando as medias e desvios
mean_cnn_PRES = np.mean(pred_cnn)
mean_mlp_PRES = np.mean(pred_mlp)
mean_dfa_PRES = np.mean(pred_dfa)
std_cnn_PRES = np.std(pred_cnn)
std_mlp_PRES = np.std(pred_mlp)
std_dfa_PRES = np.std(pred_dfa)

mean_vals_pres = [mean_cnn_PRES,mean_mlp_PRES,mean_dfa_PRES]
std_vals_pres = [std_cnn_PRES,std_mlp_PRES,std_dfa_PRES]
print(mean_vals_pres,std_vals_pres)
# Out:
# ([0.89829703500940761, 0.82382985847117696, 0.47041904883414565], [0.025293820077015999, 0.017875999554283786, 0.013747594437356347])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 10.5)
ax.bar(y_pos, mean_vals_pres, width,yerr=std_vals_pres, align='edge',
        color='red', ecolor='black')
ax.set_xticks(y_pos + width/2)
plt.ylim(0.0, 1.0)
ax.set_xticklabels(('CNN', 'MLP', 'DFA'))
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Model')
ax.set_ylabel('Mean')
ax.set_title('Precision')
plt.show()

# %%
# recall 
rec_cnn = [0.89893617021276595
,0.85106382978723405
,0.88172043010752688
,0.9027027027027027
,0.94054054054054059
,0.875
,0.88586956521739135
,0.92896174863387981
,0.85635359116022103
,0.89502762430939231]
rec_mlp = [0.78191489361702127
,0.82978723404255317
,0.79569892473118276
,0.81621621621621621
,0.80540540540540539
,0.80978260869565222
,0.81521739130434778
,0.81420765027322406
,0.8066298342541437
,0.77348066298342544]
rec_dfa = [0.46685714285714286
,0.48057142857142859
,0.47657142857142859
,0.4914187643020595
,0.47368421052631576
,0.48769318832283914
,0.47534403669724773
,0.48222477064220182
,0.47933409873708382
,0.47876004592422505]
plt.plot(rec_cnn,label="CNN")
plt.plot(rec_mlp,label='MLP')
plt.plot(rec_dfa,label='DFA')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# calculando as medias e desvios
mean_cnn_REC = np.mean(rec_cnn)
mean_mlp_REC = np.mean(rec_mlp)
mean_dfa_REC = np.mean(rec_dfa)
std_cnn_REC = np.std(rec_cnn)
std_mlp_REC = np.std(rec_mlp)
std_dfa_REC = np.std(rec_dfa)

mean_vals_rec = [mean_cnn_REC,mean_mlp_REC,mean_dfa_REC]
std_vals_rec = [std_cnn_REC,std_mlp_REC,std_dfa_REC]
print(mean_vals_rec)
# Out:
# [0.89161762026716551, 0.80483408215231722, 0.47924591151519724]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 10.5)
ax.bar(y_pos, mean_vals_rec, width,yerr=std_vals_rec, align='edge',
        color='red', ecolor='black')
ax.set_xticks(y_pos + width/2)
plt.ylim(0.0, 1.0)
ax.set_xticklabels(('CNN', 'MLP', 'DFA'))
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Model')
ax.set_ylabel('Mean')
ax.set_title('Recall')
plt.show()

# %%
# f1 
f1_cnn = [.89943734675294595
,0.85398267866678557
,0.88114873613660583
,0.90203298181330116
,0.9406684992234865
,0.87377069095657378
,0.87713327343057534
,0.92788994418599524
,0.85623075939199678
,0.89466138423262387]
f1_mlp = [0.7833394123104761
,0.83522274505948524
,0.7895281875096356
,0.81077501284788478
,0.81228189064522693
,0.807025308576515
,0.81378846162499119
,0.81003563369921172
,0.8083458367984433
,0.77203090987797618]
f1_dfa = [0.44120054382061774
,0.45384208830295109
,0.44691937584430036
,0.46064241263064482
,0.44386314979854918
,0.45928025859342281
,0.45341178966881002
,0.45736672760344393
,0.44685699138699286
,0.4528565357483994]
plt.plot(f1_cnn,label="CNN")
plt.plot(f1_mlp,label='MLP')
plt.plot(f1_dfa,label='DFA')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# calculando as medias e desvios
mean_cnn_F = np.mean(f1_cnn)
mean_mlp_F = np.mean(f1_mlp)
mean_dfa_F = np.mean(f1_dfa)
std_cnn_F = np.std(f1_cnn)
std_mlp_F = np.std(f1_mlp)
std_dfa_F = np.std(f1_dfa)

mean_vals_f = [mean_cnn_F,mean_mlp_F,mean_dfa_F]
std_vals_f = [std_cnn_F,std_mlp_F,std_dfa_F]
print(mean_vals_f)
# Out:
# [0.89069562947908898, 0.80423733989498447, 0.45162398733981313]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 10.5)
ax.bar(y_pos, mean_vals_f, width,yerr=std_vals_f, align='edge',
        color='red', ecolor='black')
ax.set_xticks(y_pos + width/2)
plt.ylim(0.0, 1.0)
ax.set_xticklabels(('CNN', 'MLP', 'DFA'))
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Model')
ax.set_ylabel('Mean')
ax.set_title('F1')
plt.show()

# %%
# final result
n_groups = 3

#means_men = (20, 35, 30, 35, 27)
#std_men = (2, 3, 4, 1, 2)

#means_women = (25, 32, 34, 20, 25)
#std_women = (3, 5, 2, 3, 3)

#means_women2 = (25, 32, 34, 20, 25)
#std_women2 = (3, 5, 2, 3, 3)

print (std_vals_acu[0], std_vals_pres[0], std_vals_rec[0], std_vals_f[0])
print (std_vals_acu[1], std_vals_pres[1], std_vals_rec[1], std_vals_f[1])
print (std_vals_acu[2], std_vals_pres[2], std_vals_rec[2], std_vals_f[2])
fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.5

opacity = 0.8
error_config = {'ecolor': '0.3'}
fig.set_size_inches(15.5, 10.5)
rects1 = plt.bar(index, mean_vals_acu, (bar_width/2)-0.1,
                 alpha=opacity,
                 color='w',
                 yerr=std_vals_acu,
                 error_kw=error_config,
                 hatch='/',
                 label='Accuracy')

rects2 = plt.bar(index + bar_width/2 - 0.1, mean_vals_pres, (bar_width/2)-0.1,
                 alpha=opacity,
                 color='w',
                 yerr=std_vals_pres,
                 error_kw=error_config,
                 hatch='//',
                 label='Precision')
rects3 = plt.bar(index + bar_width/2 + bar_width/2 - 0.2, mean_vals_rec, (bar_width/2)-0.1,
                 alpha=opacity,
                 color='w',
                 yerr=std_vals_rec,
                 error_kw=error_config,
                 hatch='*',
                 label='Recall')
rects4 = plt.bar(index + bar_width/2 + bar_width/2 + bar_width/2 - 0.3, mean_vals_f, (bar_width/2)-0.1,
                 alpha=opacity,
                 color='w',
                 yerr=std_vals_f,
                 hatch='o',
                 error_kw=error_config,
                 label='F1')


plt.xlabel('Models',fontsize=25)
plt.ylabel('Scores',fontsize=25)
plt.title('Metrics means and standard deviations ',fontsize=25)
plt.xticks(index + bar_width/1.6, ('CNN', 'MLP', 'DFA'), fontsize=15)

plt.legend()
plt.plot()
# Out:
# (0.026965544477021333, 0.025293820077015999, 0.026965544477021333, 0.026830183361571124)
# (0.016024062849340309, 0.017875999554283786, 0.016024062849340309, 0.017051054591432982)
# (0.0066121166264896765, 0.013747594437356347, 0.0066121166264896765, 0.006295246845661428)
# []
